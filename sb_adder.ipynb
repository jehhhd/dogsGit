# %%
import pandas as pd
import numpy as np

# %%
sb = pd.read_csv('betwatch_prices.csv')
sb['Track']=sb['track_name'].str.lower()
sb=sb.rename(columns={'race_date':'Date'})
sb['DogName']=sb['name'].str.lower()

for i in range(1,11):
    sb['DogName'] = sb['DogName'].str.strip(str(i)+'.').str.strip()
    
sb=sb[['Date','DogName','price']]
sb
# Out:
#               Date           DogName  price
# 0       2022-11-07        extra gold    5.0
# 1       2022-11-07   homebush classy    7.5
# 2       2022-11-07    homebush geoff    3.0
# 3       2022-11-07       jokes on us    9.0
# 4       2022-11-07     homebush axel   11.0
# ...            ...               ...    ...
# 655275  2024-02-25  datsthewaytodoit    0.0
# 655276  2024-02-25      ashway amber    0.0
# 655277  2024-02-25      ellie eithne    0.0
# 655278  2024-02-25     charlies eske    0.0
# 655279  2024-02-25      mohican chad    0.0
#
# [655280 rows x 3 columns]

# %%
a = pd.read_csv('allRaces1.csv')
a
# Out:
#          Place          DogName  Box  Weight  StartPrice    PIR  Split  \
# 0          1.0      raine allen  1.0    27.4         2.4    111   6.68
# 1          2.0       surf a lot  2.0    32.8         6.3    332   7.01
# 2          3.0      pingin' bee  6.0    25.5         9.3    443   7.24
# 3          4.0  lucas the great  7.0    32.2         9.1    655   7.31
# 4          5.0            quavo  4.0    28.9         3.4    766   7.38
# ...        ...              ...  ...     ...         ...    ...    ...
# 2031384    4.0   marionvale gal  1.0    26.6         4.4    NaN  11.10
# 2031385    NaN     quantum leap  NaN     NaN         1.0    NaN    NaN
# 2031386    NaN       bella prue  NaN     NaN         1.0    NaN    NaN
# 2031387    4.0      rise as one  7.0    32.2         8.0    NaN  11.59
# 2031388    3.0     simply black  4.0    27.5         1.9  543.0   6.68
#
#          RunTime      RaceId  Distance       RaceGrade          Track  \
# 0          28.66   335811282       500  Restricted Win        bendigo
# 1          28.82   335811282       500  Restricted Win        bendigo
# 2          28.93   335811282       500  Restricted Win        bendigo
# 3          29.03   335811282       500  Restricted Win        bendigo
# 4          29.05   335811282       500  Restricted Win        bendigo
# ...          ...         ...       ...             ...            ...
# 2031384    23.68  1008720936       400               6  mount gambier
# 2031385      NaN  1008720935       400               6  mount gambier
# 2031386      NaN  1008720935       400               6  mount gambier
# 2031387    24.52  1008720935       400               6  mount gambier
# 2031388    20.55  1008718924       340               6       gunnedah
#
#                date TrainerLName TrainerFName
# 0        2018-07-01     Grenfell            C
# 1        2018-07-01        Tyley            C
# 2        2018-07-01      Dapiran            P
# 3        2018-07-01     Hamilton            E
# 4        2018-07-01      Dapiran            P
# ...             ...          ...          ...
# 2031384  2024-03-21          poo          poo
# 2031385  2024-03-21          poo          poo
# 2031386  2024-03-21          poo          poo
# 2031387  2024-03-21          poo          poo
# 2031388  2024-03-21          poo          poo
#
# [2031389 rows x 15 columns]

# %%
import os 
tracks = os.listdir('class2')
for track in tracks:
    if track != '.DS_Store': 
        print(track)
        data = pd.read_csv('class2/'+track)
        data2 = pd.merge(data,a,how='inner',on=['RaceId','RunTime'])
        for col in list(data2.columns):
            if('_x' in col):
                data2=data2.rename(columns={col:col.strip('_x')})

        cols = ['DogName','RunTime', 'Split', 'Place', 'Date', 'RaceId', 'Distance',
           'Weight', 'StartPrice', 'mean_place',
           'mean_in_race_pos', 'time_z_avg', 'split_z_avg', 'pred_split1', 't1',
           't2', 't3', 't4', 't5', 'last_5_avg', 'in_form', 'ctime_z_avg',
           'csplit_z_avg', 'pred_split2', 'at_cas_dist_time',
           'at_cas_dist_time_avg', 'at_cas_perc', 'in_form2', 'faster_inside',
           'next_to_faster', 'collision', 'first_out', 'pir1', 'pir2', 'pir3',
           'Win', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'i1', 'i2']
        data2=data2[cols]

        data3=pd.merge(data2,sb,how='left')
        data3=data3[data3['price']!=0]
        data3=data3.drop_duplicates(subset=['DogName','RunTime','Date'],keep='first')
        
        data3.to_csv('class4/'+track)
# Out:
# richmond.csv
# townsville.csv
# rockhampton.csv
# nowra.csv
# maitland.csv
# wentworth park.csv
# gosford.csv
# hobart.csv
# albion park.csv
# goulburn.csv
# richmond straight.csv
# angle park.csv
# darwin.csv
# bendigo.csv
# murray bridge1.csv
# wagga.csv
# gunnedah.csv
# rockhamtpon.csv
# murray bridge.csv
# warragul.csv
# grafton.csv
# healesville.csv
# shepparton.csv
# the meadows.csv
# bulli.csv
# ipswich.csv
# cannington.csv
# bundaberg.csv
# traralgon.csv
# geelong.csv
# warrnambool.csv
# dapto.csv
# capalaba.csv
# launceston.csv
# the gardens.csv
# gawler.csv
# casino.csv
# sale.csv
# dubbo.csv
# ballarat.csv
# mount gambier.csv
# mandurah.csv
# horsham.csv
# sandown park.csv
