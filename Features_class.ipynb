# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import matplotlib.pyplot as plt
import json

# %%
races = pd.read_csv('allRaces1.csv', index_col=False)
for col in list(races.columns):
    if('Unna' in col):
        races=races.drop(columns=[col])
print(races.dtypes)
# Out:
# Place           float64
# DogName          object
# Box             float64
# Weight          float64
# StartPrice      float64
# PIR              object
# Split           float64
# RunTime         float64
# RaceId            int64
# Distance          int64
# RaceGrade        object
# Track            object
# date             object
# TrainerLName     object
# TrainerFName     object
# dtype: object

# %%
#races=races.drop(columns='Unnamed: 0')
races['date']=pd.to_datetime(races['date'],errors='coerce')
races['Place'] = pd.to_numeric(races['Place'], errors='coerce')
races = races.dropna(subset=['Place','Track'])
races['Place'] = races['Place'].astype(int)
races['Box']=races['Box'].astype(int)
races['TrainerName']=races['TrainerFName']+' '+races['TrainerLName']
races=races.drop(columns=['TrainerLName','TrainerFName'])
races['PIR']=races['PIR'].astype(str)
races
# Out:
#          Place          DogName  Box  Weight  StartPrice    PIR  Split  \
# 0            1      raine allen    1    27.4         2.4    111   6.68
# 1            2       surf a lot    2    32.8         6.3    332   7.01
# 2            3      pingin' bee    6    25.5         9.3    443   7.24
# 3            4  lucas the great    7    32.2         9.1    655   7.31
# 4            5            quavo    4    28.9         3.4    766   7.38
# ...        ...              ...  ...     ...         ...    ...    ...
# 2023832      7     loot to boot    6    22.9        81.0  227.0   5.67
# 2023833      2       kelly bolt    7    30.4        34.0  563.0   5.76
# 2023834      4         bradshaw    8    32.1         9.5  776.0   5.78
# 2023836      3   computer model    2    31.9         3.3  422.0   5.52
# 2023837      6     walking tora    8    29.1         5.5    nan    NaN
#
#          RunTime      RaceId  Distance       RaceGrade           Track  \
# 0          28.66   335811282       500  Restricted Win         bendigo
# 1          28.82   335811282       500  Restricted Win         bendigo
# 2          28.93   335811282       500  Restricted Win         bendigo
# 3          29.03   335811282       500  Restricted Win         bendigo
# 4          29.05   335811282       500  Restricted Win         bendigo
# ...          ...         ...       ...             ...             ...
# 2023832    31.48  1007029069       520          Maiden  wentworth park
# 2023833    30.47  1007029069       520          Maiden  wentworth park
# 2023834    31.18  1007029069       520          Maiden  wentworth park
# 2023836    30.37  1007029070       520               7  wentworth park
# 2023837    19.09  1006693869       320          Maiden           wagga
#
#               date TrainerName
# 0       2018-07-01  C Grenfell
# 1       2018-07-01     C Tyley
# 2       2018-07-01   P Dapiran
# 3       2018-07-01  E Hamilton
# 4       2018-07-01   P Dapiran
# ...            ...         ...
# 2023832 2024-03-15     poo poo
# 2023833 2024-03-15     poo poo
# 2023834 2024-03-15     poo poo
# 2023836 2024-03-15     poo poo
# 2023837 2024-03-15     poo poo
#
# [2008002 rows x 14 columns]

# %%
'''a = races[races['Track']=='hobart']
a = a[a['Distance']==278]
ls = list(set(a['RaceId']))

for p in ls:
    races = races[races['RaceId']!=p]
    
a = races[races['Track']=='hobart']
a = a[a['Distance']==515]
ls = list(set(a['RaceId']))

for p in ls:
    races = races[races['RaceId']!=p]'''
# Out:
# "a = races[races['Track']=='hobart']\na = a[a['Distance']==278]\nls = list(set(a['RaceId']))\n\nfor p in ls:\n    races = races[races['RaceId']!=p]\n    \na = races[races['Track']=='hobart']\na = a[a['Distance']==515]\nls = list(set(a['RaceId']))\n\nfor p in ls:\n    races = races[races['RaceId']!=p]"

# %%
# races['Track']=np.where(races['Track'].str.contains('murray'),'murray bridge',races['Track'])
# races['Track']=np.where(races['Track'].str.contains('dport @'),'hobart',races['Track'])

dick = {}

for x in list(races['Track'].unique()):
    
    dick[x] = []
    
    print(x)
    cas=races[races['Track']==x]
    for i in list(cas['Distance'].unique()):
        print(i,cas[cas['Distance']==i].shape[0])
        if cas[cas['Distance']==i].shape[0] > 7000:
            dick[x].append(i)
dick
# Out:
# bendigo
# 500 15312
# 425 38665
# 660 930
# sandown park
# 515 35277
# 595 8322
# 715 2330
# sale
# 440 24004
# 520 5350
# 650 800
# 510 667
# 435 2576
# 640 126
# albion park
# 331 25608
# 395 25783
# 520 32014
# 600 4438
# 710 1851
# mount gambier
# 512 11078
# 400 22149
# 600 1665
# 732 316
# 277 88
# 305 2238
# angle park
# 388 9619
# 515 15502
# 600 2251
# 731 845
# 342 10155
# 530 11135
# 730 830
# 595 1593
# shepparton
# 390 10291
# 450 22828
# 650 881
# 385 22887
# traralgon
# 315 946
# 395 11028
# 525 737
# 665 7
# 595 46
# 500 1743
# 350 6765
# 450 4100
# ballarat
# 450 25210
# 545 5017
# 390 29013
# 660 748
# bathurst
# 450 5652
# 307 9692
# 520 2726
# 618 333
# 700 17
# nowra
# 365 13849
# 630 421
# 520 4549
# 722 28
# launceston
# 515 10542
# 278 11840
# 600 628
# 720 124
# grafton
# 407 4036
# 305 4187
# 610 300
# 480 1232
# 350 10312
# 450 5248
# 660 180
# northam
# 297 6790
# 509 3528
# 588 156
# 721 15
# warragul
# 460 24242
# 400 37483
# 680 511
# horsham
# 410 21020
# 485 7746
# geelong
# 460 19834
# 400 31803
# 520 1410
# 596 130
# 680 326
# lismore
# 420 6885
# 520 2609
# 635 144
# 259 3538
# cannington
# 380 30482
# 520 26789
# 275 20168
# 600 3664
# 715 1919
# maitland
# 400 12138
# 450 5954
# 565 1022
# devonport
# 452 13837
# 580 382
# cairns
# 410 248
# 544 23
# ipswich
# 431 42679
# 520 16719
# 630 2019
# 732 105
# 288 17639
# cranbourne
# 520 7244
# 311 20426
# 699 290
# the meadows
# 525 38536
# 600 8375
# 725 1077
# 730 664
# darwin
# 312 12931
# 383 8524
# 537 2441
# richmond
# 400 18005
# 618 1667
# 330 15953
# 535 5460
# 717 82
# 790 8
# 401 8420
# 320 10778
# 520 4027
# 622 853
# 722 35
# wentworth park
# 520 34620
# 720 2484
# 280 2595
# rockhampton
# 407 19837
# 510 3115
# hobart
# 340 7849
# 461 14886
# 599 632
# 278 195
# 515 96
# casino
# 411 12713
# 620 376
# 484 4570
# 300 8753
# goulburn
# 350 17107
# 440 10624
# dapto
# 520 9998
# 600 1683
# 297 10234
# 729 53
# healesville
# 300 31731
# 350 29390
# strathalbyn
# 319 437
# 416 211
# 536 140
# the gardens
# 515 13199
# 400 29768
# 600 2260
# 715 426
# 272 9135
# wagga
# 400 5902
# 320 9993
# 525 2399
# 760 6
# bulli
# 472 4784
# 400 10344
# 515 879
# 590 380
# 340 3336
# bundaberg
# 460 13197
# 550 1748
# 531 495
# 315 668
# tamworth
# 457 310
# 340 2067
# 402 1339
# moree
# 302 1405
# 421 440
# 551 28
# taree
# 314 5566
# 392 4445
# 537 1309
# gawler
# 400 32968
# 531 9003
# 643 1327
# muswellbrook
# hatrick
# 520 707
# 305 1239
# 755 30
# limerick
# 480 3671
# 320 109
# 526 98
# 503 440
# 686 119
# 549 171
# mullingar
# 480 3761
# 366 163
# 320 85
# 549 12
# 503 17
# waterford
# 480 3987
# 297 59
# 526 40
# 668 91
# 503 110
# thurles park
# 480 1657
# 302 71
# 521 166
# curraheen park
# 503 274
# 480 3093
# 686 145
# 302 494
# 526 118
# dundalk
# 480 1627
# 366 1435
# 503 106
# 526 59
# 567 27
# 613 4
# 549 36
# drumbo park
# 480 842
# 306 873
# 526 32
# 503 43
# 764 4
# clonmel
# 480 2244
# 503 200
# 274 517
# 686 6
# manukau
# 318 2006
# 527 665
# 779 23
# henlow
# 460 1917
# 550 196
# 692 18
# 277 79
# manawatu
# 660 226
# 410 84
# 375 1046
# 457 594
# pelaw grange
# 435 1537
# ascot park
# 390 1052
# 457 403
# cambridge
# 375 637
# 457 324
# 650 49
# 747 8
# the valley
# 460 407
# 260 268
# 645 45
# {'bendigo': [500, 425],
#  'sandown park': [515, 595],
#  'sale': [440],
#  'albion park': [331, 395, 520],
#  'mount gambier': [512, 400],
#  'angle park': [388, 515, 342, 530],
#  'shepparton': [390, 450, 385],
#  'traralgon': [395],
#  'ballarat': [450, 390],
#  'bathurst': [307],
#  'nowra': [365],
#  'launceston': [515, 278],
#  'grafton': [350],
#  'northam': [],
#  'warragul': [460, 400],
#  'horsham': [410, 485],
#  'geelong': [460, 400],
#  'lismore': [],
#  'cannington': [380, 520, 275],
#  'maitland': [400],
#  'devonport': [452],
#  'cairns': [],
#  'ipswich': [431, 520, 288],
#  'cranbourne': [520, 311],
#  'the meadows': [525, 600],
#  'darwin': [312, 383],
#  'richmond': [400, 330, 401, 320],
#  'wentworth park': [520],
#  'rockhampton': [407],
#  'hobart': [340, 461],
#  'casino': [411, 300],
#  'goulburn': [350, 440],
#  'dapto': [520, 297],
#  'healesville': [300, 350],
#  'strathalbyn': [],
#  'the gardens': [515, 400, 272],
#  'wagga': [320],
#  'bulli': [400],
#  'bundaberg': [460],
#  'tamworth': [],
#  'moree': [],
#  'taree': [],
#  'gawler': [400, 531],
#  'muswellbrook': [],
#  'townsville': [380, 498],
#  'dubbo': [318, 400],
#  'wauchope': [],
#  'temora': [330],
#  'broken hill': [],
#  'armidale': [],
#  'young': [],
#  'port augusta': [],
#  'kempsey': [],
#  'coonamble': [],
#  'mandurah': [405, 490, 302],
#  'capalaba': [366],
#  'cowra': [],
#  'lithgow': [],
#  'mudgee': [],
#  'coonabarabran': [],
#  'potts park': [],
#  'warrnambool': [390, 450],
#  'gosford': [388],
#  'murray bridge': [395, 300],
#  'gunnedah': [340],
#  'richmond straight': [324],
#  'canberra': [],
#  'monmore': [480],
#  'kinsley': [],
#  'nottingham': [],
#  'oxford': [],
#  'addington': [],
#  'doncaster': [],
#  'enniscorthy': [],
#  'swindon': [],
#  'towcester': [],
#  'yarmouth': [],
#  'youghal': [],
#  'romford': [400],
#  'sheffield': [],
#  'perry barr': [],
#  'suffolk downs': [],
#  'hove': [],
#  'tralee': [],
#  'crayford': [],
#  'central park': [],
#  'sunderland': [],
#  'newcastle': [480],
#  'kilkenny': [],
#  'harlow': [],
#  'lifford': [],
#  'newbridge': [],
#  'shelbourne park': [],
#  'galway': [],
#  'hatrick': [],
#  'limerick': [],
#  'mullingar': [],
#  'waterford': [],
#  'thurles park': [],
#  'curraheen park': [],
#  'dundalk': [],
#  'drumbo park': [],
#  'clonmel': [],
#  'manukau': [],
#  'henlow': [],
#  'manawatu': [],
#  'pelaw grange': [],
#  'ascot park': [],
#  'cambridge': [],
#  'the valley': []}

# %%
trk='launceston'
cas=races[races['Track']==trk]

if(trk=='mandurah'):
    cas['Distance']=np.where(cas['Distance']==488,490,cas['Distance'])

for p in list(set(cas['RaceId'])):
    a = cas[cas['RaceId']==p]
    if a.shape[0]<7:
        cas=cas[cas['RaceId']!=p]

cas.reset_index(drop=True, inplace=True)
cas['Distance']=cas['Distance'].astype(int)
print(cas['Distance'].unique())

cas
# Out:
# [515 278 600 720]
#        Place          DogName  Box  Weight  StartPrice  PIR  Split  RunTime  \
# 0          1    jughead jones    5    32.5        5.40    0   5.11    29.94
# 1          2     lisa's dream    1    23.3        4.50    0    NaN    30.12
# 2          3        work wear    3    31.4        4.50    0    NaN    30.20
# 3          4     miss emerald    6    29.7       13.60    0    NaN    30.32
# 4          5     spirit flame    4    24.5        4.60    0    NaN    30.65
# ...      ...              ...  ...     ...         ...  ...    ...      ...
# 20781      2       orson emmy    4    26.1       41.00  0.0   5.05    16.03
# 20782      1  darryl's choice    2    26.7        1.95  0.0   4.95    15.85
# 20783      3  bridwood carter    1    33.5        8.00  0.0   5.04    16.05
# 20784      5   blazer express    8    26.6       18.00  0.0   5.09    16.31
# 20785      2     bronte maree    6    26.7        6.50  0.0   4.99    16.05
#
#            RaceId  Distance RaceGrade       Track       date TrainerName
# 0       334325475       515   Grade 6  launceston 2018-07-02   L Nichols
# 1       334325475       515   Grade 6  launceston 2018-07-02     R Watts
# 2       334325475       515   Grade 6  launceston 2018-07-02  E Medhurst
# 3       334325475       515   Grade 6  launceston 2018-07-02  E Medhurst
# 4       334325475       515   Grade 6  launceston 2018-07-02     R Watts
# ...           ...       ...       ...         ...        ...         ...
# 20781  1004321688       278         3  launceston 2024-03-11     poo poo
# 20782  1004321688       278         4  launceston 2024-03-11     poo poo
# 20783  1004321688       278         4  launceston 2024-03-11     poo poo
# 20784  1004321687       278         1  launceston 2024-03-11     poo poo
# 20785  1004321687       278         3  launceston 2024-03-11     poo poo
#
# [20786 rows x 14 columns]

# %%
dogs_done = set()
dog_races = {}


for i in range(1,cas.shape[0]+1):
    index = cas.shape[0]-i
    name = cas.iloc[index,1]
    if(name not in dogs_done):
        dog_past_race = races[races['DogName']==name]
        dog_races[name]=dog_past_race
        dogs_done.add(name)
    
    if(i%1000==0):
        print(i)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000

# %%
'''trainers_done = set()
trainer_races = {}


for i in range(1,cas.shape[0]):
    index = cas.shape[0]-i
    name = cas.iloc[index,13]

    if(name not in trainers_done):
        dog_past_race = races[races['TrainerName']==name]
        trainer_races[name]=dog_past_race
        trainers_done.add(name)
    
    if(i%1000==0):
        print(i)'''
# Out:
# "trainers_done = set()\ntrainer_races = {}\n\n\nfor i in range(1,cas.shape[0]):\n    index = cas.shape[0]-i\n    name = cas.iloc[index,13]\n\n    if(name not in trainers_done):\n        dog_past_race = races[races['TrainerName']==name]\n        trainer_races[name]=dog_past_race\n        trainers_done.add(name)\n    \n    if(i%1000==0):\n        print(i)"

# %%
'''unique_track_dist={}
tracks = races['Track'].unique()
for i in range(tracks.size):
    dic={}
    track=tracks[i]
    df=races[races['Track']==track]
    dists = df['Distance'].unique()
    for i in dists:
        df2=df[df['Distance']==i]
        ls=[df2['Split'].mean(),df2['Split'].std(),df2['RunTime'].mean(),df2['RunTime'].std()]
        dic[str(i)]=ls
    unique_track_dist[track]=dic

with open('parameters.json', 'w') as json_file:
    json.dump(unique_track_dist, json_file)'''
    
with open('parameters.json','r') as json_file:
    unique_track_dist = json.load(json_file)

# %%
unique_races = {}
unique_ids = cas['RaceId'].unique()

for i in range(unique_ids.size): 
    race = cas[cas['RaceId']==unique_ids[i]]
    race = race.sort_values(by='Box')
    race.reset_index(drop=True, inplace=True)
    race['psplit']=None
    for j in range(race.shape[0]):
        name = race.iloc[j,1]
        past = dog_races[name]  
        
        date = race['date'][0]
        past = past[past['date']<date]
        past = past.sort_values(by='date')   
        
        past = past[past['Track']==trk]
        pred_split=0

        past.reset_index(drop=True, inplace=True)
        for k in range(past.shape[0]):
            if(pd.isna(past.iloc[k,6])==False):
                params = unique_track_dist[trk][str(past.iloc[k,9])]
                pred_split+=((past.iloc[k,6]-params[0])/params[1])
        if past.shape[0]!=0:
            pred_split/=past.shape[0]
        race.iloc[j,14]=pred_split
            
            
    unique_races[unique_ids[i]]=race
    
    if(i%1000==0):
        print(i)
# Out:
# 0
# 1000
# 2000

# %%
def pir_function(pirs,places):
    start=0
    mid=0
    fin=0
    for i in range(len(pirs)):
        pir = pirs[i]

        if(pd.isna(pir) or pir in ['nan','0','0.0',0] ):
            start+=4.5
            mid+=4.5
            fin+=4.5
        else: 
            try:
                if('.' in pir):
                    pir = str(int(float(pir)))


                if(len(pir)==1):
                    start+=int(pir)-places[i]
                    mid+=int(pir)-places[i]
                    fin+=int(pir)-places[i]
                elif(len(pir)==2):
                    start+=int(pir[0])-places[i]
                    mid+=int(pir[1])-places[i]
                    fin+=int(pir[1])-places[i]
                elif(len(pir)==3):
                    start+=int(pir[0])-places[i]
                    mid+=int(pir[1])-places[i]
                    fin+=int(pir[2])-places[i]
                elif(len(pir)==4):
                    start+=int(pir[0])-places[i]
                    mid+=(int(pir[1])+int(pir[2]))/2-places[i]
                    fin+=int(pir[3])-places[i]
                elif(len(pir)==5):
                    start+=(int(pir[0])+int(pir[1]))/2-places[i]
                    mid+=int(pir[2])-places[i]
                    fin+=(int(pir[3])+int(pir[4]))/2-places[i]
                elif(len(pir)==6):
                    start+=(int(pir[0])+int(pir[1]))/2-places[i]
                    mid+=(int(pir[2])+int(pir[3]))/2-places[i]
                    fin+=(int(pir[5])+int(pir[4]))/2-places[i]
                else:
                    start+=4.5-places[i]
                    mid+=4.5-places[i]
                    fin+=4.5-places[i]
            except:
                start+=4.5-places[i]
                mid+=4.5-places[i]
                fin+=4.5-places[i]


    start/=len(pirs)
    mid/=len(pirs)
    fin/=len(pirs)
    return([start,mid,fin])

# %%
duds = []
final_result=[]
df=''
last_5=''
last_2=''
trainer=''
race=''

for i in range(0,cas.shape[0]):
# for i in range(30500,31000):
    row = cas.iloc[i,]

    name = row['DogName']
    trainer = row['TrainerName']
    date = row['date']

    df = dog_races[name]
    df = df[df['date']<date]
    df=df.sort_values(by='date')

    '''trainer = trainer_races[row['TrainerName']]
#     trainer = trainer[trainer['Track']==trk]
    trainer = trainer[trainer['date']<date]'''

    if(df.shape[0]<5):
        duds.append(row['RaceId'])
    else:
        #last races

        time_z_avg = 0
        split_z_avg = 0

        for j in range(df.shape[0]):
            row2 = df.iloc[j,]
#           
            params = unique_track_dist[row2['Track']][str(row2['Distance'])]

            if(pd.isna(row2['Split'])==False):
                split_z_avg+=((row2['Split']-params[0])/params[1])
            if(pd.isna(row2['RunTime'])==False):
                time_z_avg+=((row2['RunTime']-params[2])/params[3])

        time_z_avg/=df.shape[0]
        split_z_avg/=df.shape[0]

        last_5_times=[]

        last_5 =df.tail(5)
        for j in range(5):
            row2 = last_5.iloc[j,]
#           
            params = unique_track_dist[row2['Track']][str(row2['Distance'])]

            if(pd.isna(row2['RunTime'])==False):
                last_5_times.append((row2['RunTime']-params[2])/params[3])

        last_5_times_avg=sum(last_5_times)/5
        in_form=0
        if(last_5_times_avg<time_z_avg):
            in_form=1

        track_params = unique_track_dist[row['Track']][str(row['Distance'])]

        pred_split = split_z_avg * track_params[1]+track_params[0]



        at_cas=df[df['Track']==trk]

        at_cas_perc= sum(df['Track']==trk)/df.shape[0]

        ctime_z_avg = 0
        csplit_z_avg=0


        for j in range(at_cas.shape[0]):
            row2 = at_cas.iloc[j,]

            params = unique_track_dist[row2['Track']][str(row2['Distance'])]

            if(pd.isna(row2['Split'])==False):
                csplit_z_avg+=((row2['Split']-params[0])/params[1])

            if(pd.isna(row2['RunTime'])==False):
                ctime_z_avg+=((row2['RunTime']-params[2])/params[3])
        if(at_cas.shape[0]!=0):
            ctime_z_avg/=at_cas.shape[0]
            csplit_z_avg/=at_cas.shape[0]

        pred_split2 = csplit_z_avg * track_params[1]+track_params[0]

        at_cas_dist=at_cas[at_cas['Distance']==row['Distance']]
        
        at_cas_dist_time=0
        at_cas_dist_time_avg=0
        in_form2=0

        if(at_cas_dist.shape[0]>0):
            final_row = at_cas_dist.iloc[-1,]
            at_cas_dist_time=(final_row['RunTime']-track_params[2])/track_params[3]
            at_cas_dist_time_avg=(at_cas_dist['RunTime'].mean()-track_params[2])/track_params[3]
            if(at_cas_dist_time<at_cas_dist_time_avg):
                in_form2=1








        '''if(trainer.shape[0]==0):
            mean_trainer_place=4.5
        else:
            mean_trainer_place=trainer['Place'].mean()

        trainer = trainer.tail(5)
        trainer_last_5_time_z = 0


        for j in range(trainer.shape[0]):
            row2 = trainer.iloc[j,]
            params = unique_track_dist[row2['Track']][row2['Distance']]

            if(pd.isna(row2['RunTime'])==False):
                trainer_last_5_time_z+=((row2['RunTime']-params[2])/params[3])
        if(trainer.shape[0]!=0):
            trainer_last_5_time_z/=trainer.shape[0]'''

        #faster dog inside       
        race = unique_races[row['RaceId']]

        #lane prefs setup
        #split win setup

        lane_prefs={}
        split_win=1000
        for dog in list(race['DogName']):
            races1=dog_races[dog]

            date = race['date'][0]
            races1 = races1[races1['date']<date]
            races1 = races1.sort_values(by='date') 

            line = race[race['DogName']==dog]
            
            try:
                if float(line['Split']) < split_win:
                    split_win = float(line['Split'])
            except:
                split_win=69

            mean_place=races1['Place'].mean()

            ins_mean = races1[races1['Box'].isin([1,2,3])]['Place'].mean() - mean_place
            mid_mean = races1[races1['Box'].isin([4,5,6])]['Place'].mean() - mean_place
            out_mean = races1[races1['Box'].isin([7,8])]['Place'].mean() - mean_place

            means=[ins_mean,mid_mean,out_mean]
            means = [0 if pd.isna(mean) else mean for mean in means]
            lowest=np.argmin(means)
            lane_prefs[dog]=means+[lowest]

        #split win
        split_win_result = 0
        if split_win == row['Split']:
            split_win_result = 1


        #lane preferences
        params = lane_prefs[name]

        means=params[0:3]
        best_lane=params[3]

        boxes=[[1,2,3],[4,5],[6,7,8]]
        lowest = best_lane
        box = row['Box']

        if(box<4):
            box2=0
        elif(box<6):
            box2=1
        else:
            box2=2

        mean_in_pos=means[box2]



        index= race.loc[race['Box'] == box].index[0]
        faster_inside=0
        psplit=race.iloc[index,14]


        if(pd.isna(psplit)==False):        
            for j in range(index):
                if(race.iloc[j,14]<psplit):
                    faster_inside=1
                    break

        #next to fast dog
        next_to_faster=0
        collision=0
        try:
            if(box==1):
                if(race.iloc[1,14]<psplit):
                    next_to_faster=1

            elif(box==max(race['Box'])):
                if(race.iloc[race.shape[0]-2,14]<psplit):
                    next_to_faster=1

            else:
                if(race.iloc[index-1,14]<psplit or race.iloc[index+1,14]<psplit):
                    next_to_faster=1


            #split win

            #collision

            if(box==1):
                if(lane_prefs[race.iloc[1,1]][3]<best_lane):
                    collision=1

            elif(box==max(race['Box'])):
                if(lane_prefs[race.iloc[race.shape[0]-2,1]][3]>best_lane):
                    collision=1


            else:
                if(lane_prefs[race.iloc[index-1,1]][3]>best_lane or lane_prefs[race.iloc[index+1,1]][3]<best_lane):
                    collision=1
        except:
            pass

        #first_out
        first_out=sum(race['psplit']<psplit)
        if(first_out>0):
            first_out=0
        elif(first_out==0):
            first_out=1

        #PIR
        pirs = list(df['PIR'])
        pir_res = pir_function(pirs,list(df['Place']))

        #mean place
        mean_place = df['Place'].mean()



        placing_box_res=[mean_place,mean_in_pos]
        last_5_res=[time_z_avg, split_z_avg,pred_split] + last_5_times + [last_5_times_avg,in_form]
        last_2_res=[ctime_z_avg,csplit_z_avg,pred_split2,at_cas_dist_time,at_cas_dist_time_avg,at_cas_perc,in_form2]
        #trainer_res=[mean_trainer_place,trainer_last_5_time_z]
        random=[faster_inside, next_to_faster,collision,first_out]


        cols=['RunTime','Split','Place','date','RaceId','Distance','Box','Weight','StartPrice']
        row3=list(row[cols])+placing_box_res+last_5_res+last_2_res
        row3+=random+pir_res
        final_result.append(row3)

    if(i%500==0):
        print(i)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500

# %%
colnames = ['RunTime','Split','Place','Date','RaceId','Distance','Box','Weight','StartPrice']
colnames+=['mean_place','mean_in_race_pos']
colnames+=['time_z_avg','split_z_avg','pred_split1']
colnames+=['t1','t2','t3','t4','t5','last_5_avg','in_form']
colnames+=['ctime_z_avg','csplit_z_avg','pred_split2','at_cas_dist_time','at_cas_dist_time_avg','at_cas_perc','in_form2']
#colnames+=['t_mean_place','t_5_time_z']
colnames+=['faster_inside','next_to_faster','collision','first_out','pir1','pir2','pir3']
           
df_final = pd.DataFrame(final_result,columns=colnames)
df_final['Win']=np.where(df_final['Place']==1,1,0)
for i in range(1,9):
    name = 'b'+str(i)
    df_final[name]=np.where(df_final['Box']==i,1,0)
    
df_final = df_final.drop(columns=['Box'])

# %%
i1 = []
i2 = []
for x in df_final.index:
    if df_final.loc[x,'b1'] == 1 or df_final.loc[x,'b2'] == 1 or df_final.loc[x,'b3'] == 1:
        i1.append(1)
        i2.append(0)
    elif df_final.loc[x,'b4'] == 1 or df_final.loc[x,'b5'] or df_final.loc[x,'b6']== 1:
        i1.append(0)
        i2.append(1)
    else:
        i1.append(0)
        i2.append(0)
df_final['i1'] = i1
df_final['i2'] = i2

# %%
df_final.to_csv('class2/'+trk+'.csv')
duds = set(duds)
duds = list(duds)
dc = {'Invalid':duds}
dff = pd.DataFrame(dc)

#If you change this to few_dogs you need to take out underscore, change class and change number up top
dff.to_csv('Invalid/Invalid_'+trk+'.csv')
df_final
# Out:
#        RunTime  Split  Place       Date      RaceId  Distance  Weight  \
# 0        30.75    NaN      7 2018-07-23   340684182       515    26.0
# 1        30.22    NaN      5 2018-07-23   340684189       515    33.3
# 2        16.43    NaN      4 2018-07-30   343293838       278    27.3
# 3        16.72    NaN      7 2018-07-30   343293838       278    25.2
# 4        35.47    NaN      2 2018-07-30   343293840       600    32.3
# ...        ...    ...    ...        ...         ...       ...     ...
# 17914    16.03   5.05      2 2024-03-11  1004321688       278    26.1
# 17915    15.85   4.95      1 2024-03-11  1004321688       278    26.7
# 17916    16.05   5.04      3 2024-03-11  1004321688       278    33.5
# 17917    16.31   5.09      5 2024-03-11  1004321687       278    26.6
# 17918    16.05   4.99      2 2024-03-11  1004321687       278    26.7
#
#        StartPrice  mean_place  mean_in_race_pos  ...  b1  b2  b3  b4  b5  b6  \
# 0           19.20    4.000000          0.000000  ...   0   0   0   0   0   0
# 1           13.50    3.400000         -2.400000  ...   0   0   0   0   0   0
# 2           48.30    3.857143          0.142857  ...   0   0   0   1   0   0
# 3           27.00    4.200000         -0.200000  ...   0   0   1   0   0   0
# 4            4.80    2.400000         -0.400000  ...   0   0   0   1   0   0
# ...           ...         ...               ...  ...  ..  ..  ..  ..  ..  ..
# 17914       41.00    4.244444          0.286806  ...   0   0   0   1   0   0
# 17915        1.95    2.350000          0.221429  ...   0   1   0   0   0   0
# 17916        8.00    4.090909         -0.646465  ...   1   0   0   0   0   0
# 17917       18.00    3.647727          0.579545  ...   0   0   0   0   0   0
# 17918        6.50    3.360000         -0.217143  ...   0   0   0   0   0   1
#
#        b7  b8  i1  i2
# 0       1   0   0   0
# 1       1   0   0   0
# 2       0   0   0   1
# 3       0   0   1   0
# 4       0   0   0   1
# ...    ..  ..  ..  ..
# 17914   0   0   0   1
# 17915   0   0   1   0
# 17916   0   0   1   0
# 17917   0   1   0   0
# 17918   0   0   0   1
#
# [17919 rows x 45 columns]

# %%
dc
# Out:
# {'Invalid': [410810380,
#   410810381,
#   410810382,
#   28686,
#   28684,
#   606679058,
#   606679060,
#   606679063,
#   403060764,
#   606679068,
#   606679074,
#   580851747,
#   580851748,
#   580851749,
#   515262517,
#   515262518,
#   515262519,
#   515262525,
#   591284292,
#   591284294,
#   10311,
#   591284296,
#   10320,
#   596389974,
#   596389976,
#   596389982,
#   737939553,
#   737939554,
#   857139304,
#   535478378,
#   535478379,
#   360982061,
#   360928811,
#   360928814,
#   626218541,
#   626218542,
#   842792503,
#   842792504,
#   461094459,
#   461094460,
#   842792507,
#   884739656,
#   884739657,
#   884739659,
#   884739660,
#   884739665,
#   670592596,
#   734725719,
#   734725720,
#   734725721,
#   576081515,
#   576081517,
#   520050287,
#   520050289,
#   370450034,
#   370450038,
#   370450039,
#   370450040,
#   370450041,
#   370450042,
#   520050296,
#   576081532,
#   601852424,
#   576081534,
#   689294969,
#   689294971,
#   689294977,
#   832472703,
#   832472704,
#   530388615,
#   530388616,
#   846620297,
#   400273034,
#   400273035,
#   530388618,
#   530388619,
#   530388620,
#   530388621,
#   451755664,
#   451755665,
#   451755666,
#   530388622,
#   443647636,
#   52886,
#   52887,
#   451755672,
#   500543130,
#   752129692,
#   752129693,
#   52894,
#   500543139,
#   837666489,
#   434708154,
#   434708155,
#   434708156,
#   837666490,
#   837666491,
#   837666492,
#   837666493,
#   837666494,
#   434708162,
#   832941766,
#   832941767,
#   416007890,
#   354496214,
#   354496215,
#   354496216,
#   354496217,
#   354496218,
#   434716375,
#   354496221,
#   354496222,
#   354496223,
#   689297121,
#   689297122,
#   334325475,
#   334325476,
#   334325477,
#   334325478,
#   689297124,
#   334325480,
#   334325481,
#   334325482,
#   334325483,
#   334325484,
#   334325485,
#   689297125,
#   689297129,
#   40685,
#   561770225,
#   561770226,
#   9971,
#   9970,
#   561770229,
#   815075061,
#   815075062,
#   815075063,
#   561770233,
#   815075066,
#   467595004,
#   467595006,
#   622589694,
#   622589695,
#   622589697,
#   877657857,
#   645842697,
#   645842698,
#   645842699,
#   30482,
#   724780841,
#   32553,
#   724780845,
#   829183790,
#   7982,
#   729421616,
#   829183792,
#   829183794,
#   729421619,
#   32560,
#   614166325,
#   7983,
#   614166327,
#   801455932,
#   426827582,
#   426827583,
#   614166334,
#   801455934,
#   426827586,
#   829183807,
#   426827588,
#   63300,
#   69975,
#   69976,
#   71503,
#   71504,
#   442494804,
#   71511,
#   442494813,
#   580851556,
#   580851557,
#   425377641,
#   580851563,
#   425377644,
#   425377645,
#   69984,
#   382656372,
#   425377652,
#   382656374,
#   382656377,
#   382656379,
#   382656380,
#   57219,
#   57220,
#   57224,
#   343293837,
#   343293838,
#   343293840,
#   343293841,
#   343293842,
#   343293843,
#   343293844,
#   343293845,
#   343293846,
#   343293847,
#   611211161,
#   400273306,
#   611211168,
#   24489,
#   400273322,
#   65464,
#   65465,
#   869953470,
#   26559,
#   26560,
#   26561,
#   869953480,
#   714932172,
#   869953485,
#   869953488,
#   336623571,
#   336623572,
#   336623573,
#   609365972,
#   609365974,
#   609365975,
#   683145184,
#   877658082,
#   683145192,
#   660830191,
#   870678511,
#   870678512,
#   853983218,
#   660830195,
#   853983219,
#   853983221,
#   870678513,
#   870678515,
#   870678517,
#   877658097,
#   40950,
#   40946,
#   853983228]}

# %%
# if(trk=='mandurah'):
#     df_final['Distance']=np.where(df_final['Distance']==405,400,df_final['Distance'])
    
# df_final.to_csv('class/'+trk+'.csv')

# %%
# pd.read_csv('class/mandurah.csv')['Distance'].unique()
