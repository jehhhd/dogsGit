# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import LogisticRegression
import statsmodels.formula.api as smf
import seaborn as sns
import json

# %%
def selector(data,mod):
    var = list(data.columns)
#     print(var)
    for v in var:
        if('Unnamed:' in v):
            var.remove(v)
    to_rem = ['RunTime','i2','i1','faster_inside','t1','t2','t3','t4','t5','middle_shitfest','perfect_storm2','at_cas_dist_time_avg','perfect_storm','quick_out1','faster_inside','b21','b22','b23','b1','b2','b3','b4','b5','b6','b7','b8','RaceId','Distance','StartPrice','Place','Win','Date','date','Split','Weight','split win','t_mean_place','t_5_time_z','split_z_avg']
    #to_rem = ['RunTime','t1','t2','t3','t4','t5','middle_shitfest','perfect_storm2','at_cas_dist_time_avg','perfect_storm','quick_out1','faster_inside','b21','b22','b23','b1','b2','b3','b4','b5','b6','b7','b8','RaceId','Distance','StartPrice','Place','Win','Date','date','Split','Weight','split win','t_mean_place','t_5_time_z','split_z_avg']
    for v in to_rem:
        if(v in var):
            var.remove(v)
    

    start=['at_cas_dist_time_avg','faster_inside','i2','i1','split_z_avg','last_5_avg']
    #start=['split_z_avg','last_5_avg']
    runs=20
    old_MAD = np.inf
    j=0
    final_mod = ''
    X=data
    y=data['RunTime']
    total_samples = X.shape[0]
    split_index = int(total_samples * 0.8)  # 80% for training, 20% for testing

    # Split the data
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]

   

    while(j<runs):
        to_add = ''
        to_beat = old_MAD
        best_mod = ''
        for i in var:
            try:
                combination = start + [i]

                y_pred = mod.fit(X_train[combination], y_train).predict(X_test[combination])
                MAD = (((y_pred - y_test)**2).mean())**0.5
                if(MAD<to_beat):
                    to_add = i
                    to_beat = MAD
            except:
                pass


        if(old_MAD-to_beat<0.000001):
            j=runs
        else:
            j+=1
            if(to_add!=''):
                start = start + [to_add]
                old_MAD = to_beat
                if(to_add in var):
                    var.remove(to_add)
            

    return [start,old_MAD]

def selector1(data,mod):
    var = list(data.columns)
#     print(var)
    for v in var:
        if('Unnamed:' in v):
            var.remove(v)
    to_rem = ['RunTime','i2','i1','faster_inside','t1','t2','t3','t4','t5','middle_shitfest','perfect_storm2','at_cas_dist_time_avg','perfect_storm','quick_out1','faster_inside','b21','b22','b23','b1','b2','b3','b4','b5','b6','b7','b8','RaceId','Distance','StartPrice','Place','Win','Date','date','Split','Weight','split win','t_mean_place','t_5_time_z','split_z_avg']
    #to_rem = ['RunTime','t1','t2','t3','t4','t5','middle_shitfest','perfect_storm2','at_cas_dist_time_avg','perfect_storm','quick_out1','faster_inside','b21','b22','b23','b1','b2','b3','b4','b5','b6','b7','b8','RaceId','Distance','StartPrice','Place','Win','Date','date','Split','Weight','split win','t_mean_place','t_5_time_z','split_z_avg']
    for v in to_rem:
        if(v in var):
            var.remove(v)
    

    start=['at_cas_dist_time_avg','faster_inside','i2','i1','split_z_avg','last_5_avg']
    #start=['split_z_avg','last_5_avg']
    runs=20
    old_MAD = np.inf
    j=0
    final_mod = ''
    X=data
    y=data['RunTime']
    total_samples = X.shape[0]
    split_index = int(total_samples * 0.7)  # 80% for training, 20% for testing

    # Split the data
    X_train, X_test = X[-split_index:], X[:-split_index]
    y_train, y_test = y[-split_index:], y[:-split_index]

   

    while(j<runs):
        to_add = ''
        to_beat = old_MAD
        best_mod = ''
        for i in var:
            try:
                combination = start + [i]

                y_pred = mod.fit(X_train[combination], y_train).predict(X_test[combination])
                MAD = (((y_pred - y_test)**2).mean())**0.5
                if(MAD<to_beat):
                    to_add = i
                    to_beat = MAD
            except:
                pass


        if(old_MAD-to_beat<0.000001):
            j=runs
        else:
            j+=1
            if(to_add!=''):
                start = start + [to_add]
                old_MAD = to_beat
                if(to_add in var):
                    var.remove(to_add)


    return [start,old_MAD]

# %%
result={}
#tracks = ['traralgon','ipswich','albion park','cannington','geelong','ballarat','launceston','warrnambool','casino','gosford','warragul','grafton','mandurah','townsville','bendigo','shepparton','hobart']
tracks=['traralgon']
for track in tracks:
    
    track_result={}
    # track='ipswich'
    data=pd.read_csv('class/'+track+'.csv')
    #data = pd.read_csv(track+'_better_lanes.csv')
    
    i1 = []
    i2 = []
    for x in data.index:
        if data.loc[x,'b1'] == 1 or data.loc[x,'b2'] == 1 or data.loc[x,'b3'] == 1:
            i1.append(1)
            i2.append(0)
        elif data.loc[x,'b4'] == 1 or data.loc[x,'b5'] or data.loc[x,'b6']== 1:
            i1.append(0)
            i2.append(1)
        else:
            i1.append(0)
            i2.append(0)
    data['i1'] = i1
    data['i2'] = i2
    
    data.to_csv('class/'+track+'.csv')
    
    dists = data['Distance'].unique()
    for dist in dists:
        if(1==1):
            data2 = data[data['Distance']==dist]
            if(data2.shape[0]>30):
                #data2=data2.dropna()
                
                '''preds1 = ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'split_z_avg']                           
                mod1 = LogisticRegression().fit(data2[preds1], data2['split win'])
                start_score = list(np.transpose(mod1.predict_proba(data2[preds1]))[1])
                #print(list(np.transpose(mod1.predict_proba(data2[preds1]))[1]))
                data2['start_score'] = start_score
                #print(start_score)'''         
                
                x = selector(data2,LinearRegression())
                predictors=x[0]
                mad=x[1]
                print(track,dist,mad,predictors)
                track_result[int(dist)]=predictors
    result[track]=track_result
    print(track)
    
result1={}
for track in tracks:
    track_result1={}
    # track='ipswich'
    data=pd.read_csv('class/'+track+'.csv')
    #data = pd.read_csv(track+'_better_lanes.csv')
    
    dists = data['Distance'].unique()
    for dist in dists:
        if(1==1):
            data2 = data[data['Distance']==dist]
            if(data2.shape[0]>30):
                #data2=data2.dropna()
                x = selector1(data2,LinearRegression())
                predictors=x[0]
                mad=x[1]
                print(track,dist,mad,predictors)
                track_result1[int(dist)]=predictors

    result1[track]=track_result1
    print(track)

for x in result[track].keys():
    good = []
    for i in result[track][x]:
        if i in result1[track][x]:
            good.append(i)
    #if x == 461:
        #good = ['faster_inside', 'at_cas_dist_time_avg', 'mean_place', 'pred_split2', 'at_cas_dist_time', 'at_cas_perc', 'csplit_z_avg', 't3']
    #if x == 340:
        #good = ['faster_inside','at_cas_dist_time_avg','pred_split1','mean_place','time_z_avg','split_z_avg']
    result[track][x] = good
    
result
# Out:
# traralgon 315 0.2660669950094025 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'mean_place', 'pred_split2', 'pred_split1']
# traralgon 525 0.33944128214300523 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'time_z_avg', 'pir3', 'pir1', 'next_to_faster', 'at_cas_dist_time', 'pir2', 'ctime_z_avg', 'csplit_z_avg', 'pred_split2', 'in_form2', 'first_out', 'collision']
# traralgon 395 0.337402561367772 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'csplit_z_avg', 'pir1', 'at_cas_dist_time', 'mean_in_race_pos', 'next_to_faster', 'last_5_avg']
# traralgon 500 0.3518697468507936 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'ctime_z_avg', 'at_cas_perc', 'in_form2', 'in_form', 'first_out']
# traralgon 350 0.33076589511136917 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'pir3', 'mean_in_race_pos', 'pred_split1', 'pir2']
# traralgon 450 0.34301032178285656 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'in_form2', 'ctime_z_avg', 'csplit_z_avg', 'collision', 'pred_split1', 'at_cas_perc']
# traralgon
# traralgon 315 0.26318479852917775 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'csplit_z_avg', 'at_cas_perc', 'in_form', 'Unnamed: 0']
# traralgon 525 0.39477396144311844 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'Unnamed: 0', 'pir3', 'in_form', 'next_to_faster', 'mean_place', 'ctime_z_avg', 'pred_split2', 'first_out', 'at_cas_perc', 'in_form2']
# traralgon 395 0.36499546326152116 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'Unnamed: 0', 'at_cas_perc', 'at_cas_dist_time', 'next_to_faster', 'mean_in_race_pos', 'pir1', 'pir2', 'collision']
# traralgon 500 0.3202443120551854 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'time_z_avg', 'ctime_z_avg', 'in_form', 'pir3', 'pred_split1', 'at_cas_perc', 'mean_place', 'in_form2', 'csplit_z_avg', 'pred_split2']
# traralgon 350 0.29650455858004027 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'Unnamed: 0', 'time_z_avg', 'at_cas_dist_time', 'mean_in_race_pos', 'pir2', 'collision']
# traralgon 450 0.31858406988616794 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'Unnamed: 0', 'time_z_avg', 'in_form2', 'pir1', 'at_cas_perc', 'collision', 'pir2', 'mean_in_race_pos']
# traralgon
# {'traralgon': {315: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   525: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'next_to_faster',
#    'ctime_z_avg',
#    'pred_split2',
#    'in_form2',
#    'first_out'],
#   395: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'at_cas_dist_time',
#    'mean_in_race_pos',
#    'next_to_faster',
#    'last_5_avg'],
#   500: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'at_cas_perc',
#    'in_form2',
#    'in_form'],
#   350: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'mean_in_race_pos',
#    'pir2'],
#   450: ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'in_form2',
#    'collision',
#    'at_cas_perc']}}

# %%
track = tracks[0]

for dist in result[track].keys():
    data2 = data[data['Distance']==dist]
    features = result[tracks[0]][dist]
    
    data2=data2.dropna(subset=features)
    X=data2
    y=data2['RunTime']
    total_samples = X.shape[0]
    
    split_index1 = int(total_samples * 0.8)
    X_train1, X_test1 = X[:split_index1], X[split_index1:]
    y_train1, y_test1 = y[:split_index1], y[split_index1:]
    
    split_index2 = int(total_samples * 0.7)
    X_train2, X_test2 = X[-split_index2:], X[:-split_index2]
    y_train2, y_test2 = y[-split_index2:], y[:-split_index2]
    
    y_pred = LinearRegression().fit(X_train1[features], y_train1).predict(X_test1[features])
    MAD = (((y_pred - y_test1)**2).mean())**0.5
    print(track,dist,MAD,features)
    
    y_pred = LinearRegression().fit(X_train2[features], y_train2).predict(X_test2[features])
    MAD = (((y_pred - y_test2)**2).mean())**0.5
    print(track,dist,MAD,features)
# Out:
# traralgon 315 0.27853816018157584 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg']
# traralgon 315 0.27125203672873494 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg']
# traralgon 525 0.37376801019245837 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir3', 'next_to_faster', 'ctime_z_avg', 'pred_split2', 'in_form2', 'first_out']
# traralgon 525 0.43775225680004 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir3', 'next_to_faster', 'ctime_z_avg', 'pred_split2', 'in_form2', 'first_out']
# traralgon 395 0.3397326008108055 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'at_cas_dist_time', 'mean_in_race_pos', 'next_to_faster', 'last_5_avg']
# traralgon 395 0.3750109663239341 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'at_cas_dist_time', 'mean_in_race_pos', 'next_to_faster', 'last_5_avg']
# traralgon 500 0.3519763924981357 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'ctime_z_avg', 'at_cas_perc', 'in_form2', 'in_form']
# traralgon 500 0.32904388735377643 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'ctime_z_avg', 'at_cas_perc', 'in_form2', 'in_form']
# traralgon 350 0.33202573884794473 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'mean_in_race_pos', 'pir2']
# traralgon 350 0.29761087779215734 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'mean_in_race_pos', 'pir2']
# traralgon 450 0.3480018580008988 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'in_form2', 'collision', 'at_cas_perc']
# traralgon 450 0.32996372232307514 ['at_cas_dist_time_avg', 'faster_inside', 'i2', 'i1', 'split_z_avg', 'last_5_avg', 'pir1', 'in_form2', 'collision', 'at_cas_perc']

# %%
json_filename = 'preds.json'
with open(json_filename,'r') as json_file:
    dic = json.load(json_file)

for track in result.keys():
    dic[track]=result[track]
    
with open(json_filename, 'w') as json_file:
    json.dump(dic, json_file)

# %%
json_filename = 'preds.json'
with open(json_filename,'r') as json_file:
    dic = json.load(json_file)
dic
# Out:
# {'cannington': {'520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'time_z_avg',
#    'at_cas_perc'],
#   '380': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'time_z_avg',
#    'in_form2',
#    'mean_in_race_pos',
#    'collision',
#    'first_out'],
#   '275': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'time_z_avg',
#    'collision'],
#   '715': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'mean_place'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'last_5_avg']},
#  'albion park': {'520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'at_cas_perc',
#    'time_z_avg',
#    'mean_in_race_pos',
#    'collision',
#    'at_cas_dist_time',
#    'ctime_z_avg',
#    'last_5_avg',
#    'pred_split1'],
#   '395': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'time_z_avg'],
#   '710': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'pir1',
#    'last_5_avg'],
#   '331': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'in_form2'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_perc',
#    'mean_place',
#    'ctime_z_avg',
#    'mean_in_race_pos']},
#  'ipswich': {'431': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place',
#    'mean_in_race_pos',
#    'last_5_avg'],
#   '520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_perc',
#    'in_form',
#    'collision',
#    'mean_in_race_pos',
#    'last_5_avg'],
#   '288': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_dist_time',
#    'mean_in_race_pos',
#    'at_cas_perc'],
#   '630': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_perc'],
#   '732': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc']},
#  'shepparton': {'390': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'ctime_z_avg',
#    'pred_split1'],
#   '450': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'collision',
#    'ctime_z_avg'],
#   '650': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_perc',
#    'next_to_faster',
#    'in_form'],
#   '385': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pred_split2',
#    'ctime_z_avg',
#    'in_form2',
#    'pir3',
#    'last_5_avg',
#    'in_form']},
#  'townsville': {'380': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'csplit_z_avg',
#    'first_out',
#    'mean_in_race_pos',
#    'mean_place',
#    'ctime_z_avg'],
#   '498': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'at_cas_perc'],
#   '643': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'collision',
#    'time_z_avg',
#    'next_to_faster']},
#  'darwin': {'312': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'mean_in_race_pos',
#    'at_cas_dist_time',
#    'in_form2',
#    'last_5_avg'],
#   '383': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_in_race_pos',
#    'last_5_avg',
#    'pir3'],
#   '537': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'pir1',
#    'last_5_avg']},
#  'gosford': {'388': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'time_z_avg',
#    'last_5_avg'],
#   '515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'in_form2',
#    'pir3',
#    'ctime_z_avg'],
#   '603': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'mean_in_race_pos',
#    'pred_split1',
#    'last_5_avg',
#    'in_form2'],
#   '710': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg']},
#  'dapto': {'520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'in_form2',
#    'pir3',
#    'pir2',
#    'last_5_avg'],
#   '297': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pred_split1'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'first_out',
#    'in_form2',
#    'mean_in_race_pos']},
#  'grafton': {'480': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'time_z_avg',
#    't5',
#    'pir3',
#    'collision',
#    'ctime_z_avg',
#    'at_cas_perc'],
#   '407': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'time_z_avg',
#    'in_form2',
#    'i2',
#    'next_to_faster'],
#   '305': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'last_5_avg',
#    't5',
#    'next_to_faster',
#    'first_out'],
#   '610': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'time_z_avg',
#    'i2',
#    'collision',
#    'at_cas_dist_time',
#    't2'],
#   '350': ['faster_inside',
#    'at_cas_dist_time_avg',
#    't5',
#    'last_5_avg',
#    'at_cas_perc',
#    'time_z_avg',
#    'in_form2',
#    'i2',
#    'pir3',
#    'ctime_z_avg',
#    'collision',
#    't1',
#    'pir2'],
#   '450': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'mean_place',
#    'in_form2',
#    'ctime_z_avg',
#    'in_form',
#    'i2',
#    't1',
#    'mean_in_race_pos',
#    'i1'],
#   '660': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'last_5_avg',
#    'pir1',
#    'pir3',
#    'ctime_z_avg',
#    'pred_split2',
#    'at_cas_dist_time']},
#  'bendigo': {'425': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'collision',
#    'in_form2',
#    'at_cas_perc',
#    'first_out',
#    'pred_split1'],
#   '500': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'ctime_z_avg',
#    'at_cas_perc',
#    'in_form2',
#    'in_form',
#    'first_out',
#    'mean_in_race_pos'],
#   '660': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg']},
#  'richmond': {'400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'pir3',
#    'ctime_z_avg',
#    'collision',
#    'pir1',
#    'mean_in_race_pos'],
#   '330': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'time_z_avg',
#    'mean_place',
#    'pir3',
#    'at_cas_perc',
#    'in_form2'],
#   '535': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'in_form',
#    'in_form2',
#    'at_cas_perc',
#    'collision'],
#   '618': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '320': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'collision',
#    'at_cas_perc',
#    'pir2',
#    'next_to_faster'],
#   '401': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'ctime_z_avg',
#    'mean_in_race_pos',
#    'first_out'],
#   '622': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_in_race_pos',
#    'time_z_avg',
#    'in_form',
#    'collision',
#    'ctime_z_avg',
#    'csplit_z_avg',
#    'pred_split1',
#    'next_to_faster']},
#  'casino': {'411': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pir3',
#    'last_5_avg',
#    'collision'],
#   '484': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'at_cas_perc'],
#   '620': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form',
#    'at_cas_perc',
#    'pir1'],
#   '300': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'time_z_avg',
#    'pir2',
#    'pir3']},
#  'healesville': {'350': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg'],
#   '300': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'time_z_avg',
#    'ctime_z_avg',
#    'csplit_z_avg',
#    'in_form2']},
#  'ballarat': {'390': ['faster_inside',
#    'i1',
#    'i2',
#    'last_5_avg',
#    'time_z_avg',
#    't5',
#    'at_cas_dist_time',
#    'mean_place',
#    't1',
#    'csplit_z_avg',
#    'in_form',
#    'at_cas_perc',
#    'b22'],
#   '545': ['faster_inside',
#    'i1',
#    'i2',
#    'at_cas_perc',
#    'at_cas_dist_time',
#    'time_z_avg',
#    'ctime_z_avg',
#    'at_cas_dist_time_avg',
#    't3',
#    'collision'],
#   '450': ['faster_inside',
#    'i1',
#    'i2',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_dist_time',
#    't5',
#    'collision',
#    'wide_finisher',
#    'first_out',
#    'at_cas_dist_time_avg',
#    'in_form2',
#    'mean_in_race_pos',
#    't1'],
#   '660': ['faster_inside',
#    'i1',
#    'i2',
#    'time_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'at_cas_dist_time_avg',
#    'b23']},
#  'traralgon': {'315': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '525': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'next_to_faster',
#    'ctime_z_avg',
#    'pred_split2',
#    'in_form2',
#    'first_out'],
#   '395': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'at_cas_dist_time',
#    'mean_in_race_pos',
#    'next_to_faster',
#    'last_5_avg'],
#   '500': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'at_cas_perc',
#    'in_form2',
#    'in_form'],
#   '350': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'mean_in_race_pos',
#    'pir2'],
#   '450': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'in_form2',
#    'collision',
#    'at_cas_perc']},
#  'geelong': {'460': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'in_form2',
#    'collision',
#    'in_form'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'pir2',
#    'mean_place',
#    'in_form2',
#    'pir3'],
#   '520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pred_split1'],
#   '596': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pred_split1',
#    'last_5_avg',
#    'pir3'],
#   '680': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time']},
#  'angle park': {'388': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'first_out',
#    'mean_in_race_pos'],
#   '515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'time_z_avg',
#    'at_cas_perc',
#    'mean_in_race_pos',
#    'last_5_avg'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'in_form2',
#    'in_form',
#    'pir3'],
#   '731': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '530': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'in_form2',
#    'time_z_avg',
#    'mean_in_race_pos',
#    'at_cas_dist_time',
#    'last_5_avg'],
#   '595': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'first_out',
#    'time_z_avg'],
#   '342': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'ctime_z_avg',
#    'collision',
#    'in_form',
#    'in_form2'],
#   '730': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir2',
#    'ctime_z_avg',
#    'time_z_avg']},
#  'wentworth park': {'520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'time_z_avg',
#    'in_form2'],
#   '720': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'collision',
#    'ctime_z_avg'],
#   '280': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'first_out']},
#  'launceston': {'515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place'],
#   '278': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'in_form2',
#    'pir1',
#    'pir3'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place']},
#  'dubbo': {'516': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_perc',
#    'pred_split1',
#    'last_5_avg'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'mean_place'],
#   '318': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '605': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place']},
#  'maitland': {'400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'last_5_avg',
#    'mean_place',
#    'ctime_z_avg',
#    'next_to_faster'],
#   '565': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'time_z_avg',
#    'pir2',
#    'first_out'],
#   '450': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'time_z_avg',
#    'in_form2',
#    'pir3',
#    'csplit_z_avg']},
#  'rockhampton': {'407': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'next_to_faster',
#    'in_form2',
#    'ctime_z_avg'],
#   '510': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'collision',
#    'last_5_avg']},
#  'sale': {'440': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'mean_in_race_pos'],
#   '520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'collision',
#    'mean_in_race_pos',
#    'in_form',
#    'pir3'],
#   '650': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_in_race_pos'],
#   '510': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'in_form',
#    'first_out'],
#   '435': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir1',
#    'pred_split1'],
#   '640': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pred_split1',
#    'csplit_z_avg',
#    'pred_split2',
#    'at_cas_dist_time']},
#  'the gardens': {'400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'in_form2',
#    'time_z_avg',
#    'csplit_z_avg'],
#   '515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'in_form2',
#    'first_out',
#    'ctime_z_avg',
#    'mean_place'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pred_split1',
#    'csplit_z_avg',
#    'in_form2',
#    'pir1'],
#   '715': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'at_cas_perc'],
#   '272': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pred_split1',
#    'last_5_avg']},
#  'gawler': {'400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pred_split1',
#    'first_out',
#    'in_form',
#    'pred_split2'],
#   '531': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_perc',
#    'in_form2',
#    'mean_place',
#    'collision'],
#   '643': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'in_form2',
#    'pir1']},
#  'temora': {'330': ['b1',
#    'b2',
#    'b3',
#    'b4',
#    'b5',
#    'b6',
#    'b7',
#    'b8',
#    'time_z_avg',
#    'mean_in_race_pos',
#    't_5_time_z',
#    'ctime_z_avg',
#    't2',
#    'at_cas_dist_time',
#    't_mean_place',
#    'csplit_z_avg'],
#   '457': ['b1',
#    'b2',
#    'b3',
#    'b4',
#    'b5',
#    'b6',
#    'b7',
#    'b8',
#    'time_z_avg',
#    'at_cas_dist_time',
#    'mean_in_race_pos',
#    't_5_time_z',
#    't2',
#    't_mean_place',
#    'mean_place',
#    'first_out',
#    'pir2',
#    'at_cas_perc',
#    't5',
#    't4',
#    'at_cas_dist_time_avg',
#    'in_form2',
#    'collision',
#    'csplit_z_avg',
#    'pred_split1',
#    'next_to_faster']},
#  'hobart': {'461': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'in_form2',
#    'pir2',
#    'at_cas_perc',
#    'time_z_avg',
#    'ctime_z_avg',
#    'last_5_avg'],
#   '340': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'pred_split1'],
#   '599': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form',
#    'in_form2',
#    'time_z_avg']},
#  'gunnedah': {'340': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '431': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'in_form2',
#    'mean_place',
#    'ctime_z_avg',
#    'mean_in_race_pos',
#    'csplit_z_avg',
#    'collision'],
#   '527': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'in_form2',
#    'first_out',
#    'mean_place',
#    'pir1',
#    'ctime_z_avg']},
#  'mount gambier': {'600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg'],
#   '512': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'pir2',
#    'first_out'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'time_z_avg',
#    'collision',
#    'pred_split2',
#    'last_5_avg'],
#   '305': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'first_out',
#    'pred_split1']},
#  'warrnambool': {'390': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir3',
#    'time_z_avg',
#    'collision',
#    'in_form',
#    'in_form2',
#    'last_5_avg',
#    'next_to_faster'],
#   '450': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place',
#    'pir3',
#    'at_cas_perc',
#    'ctime_z_avg'],
#   '650': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pred_split1',
#    'mean_place']},
#  'warragul': {'460': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place',
#    'at_cas_perc',
#    'collision',
#    'ctime_z_avg'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place',
#    'at_cas_dist_time',
#    'mean_in_race_pos',
#    'collision'],
#   '680': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2']},
#  'mandurah': {'405': ['faster_inside',
#    'i1',
#    'i2',
#    'at_cas_dist_time_avg',
#    'last_5_avg',
#    't_mean_place',
#    'in_form2',
#    't1',
#    'pir1',
#    'first_out',
#    'next_to_faster'],
#   '302': ['faster_inside',
#    'i1',
#    'i2',
#    'last_5_avg',
#    'at_cas_dist_time',
#    't_mean_place',
#    'collision',
#    'first_out'],
#   '490': ['faster_inside',
#    'i1',
#    'i2',
#    'ctime_z_avg',
#    't_mean_place',
#    'in_form2',
#    'time_z_avg',
#    'in_form',
#    'at_cas_perc'],
#   '647': ['faster_inside', 'i1', 'i2', 't_mean_place', 'collision'],
#   '300': ['faster_inside',
#    'i1',
#    'i2',
#    't3',
#    't_mean_place',
#    'next_to_faster',
#    'pir2'],
#   '400': ['faster_inside',
#    'i1',
#    'i2',
#    'ctime_z_avg',
#    'mean_place',
#    'in_form',
#    't_5_time_z',
#    'pir1'],
#   '488': ['faster_inside', 'i1', 'i2', 'ctime_z_avg', 'next_to_faster']},
#  'warr_test': {'450': ['start_score',
#    'StartPrice',
#    'last_5_avg',
#    'pir3',
#    'at_cas_perc',
#    'next_to_faster',
#    'at_cas_dist_time',
#    't3',
#    't2']},
#  'horsham': {'485': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'ctime_z_avg',
#    'in_form2',
#    'pred_split2',
#    'pir1'],
#   '410': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'mean_place',
#    'last_5_avg',
#    'first_out',
#    'next_to_faster',
#    'at_cas_perc']},
#  'bulli': {'515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'time_z_avg',
#    'at_cas_perc',
#    'csplit_z_avg',
#    'mean_in_race_pos'],
#   '472': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'next_to_faster',
#    'mean_in_race_pos',
#    'at_cas_dist_time',
#    'in_form',
#    'ctime_z_avg',
#    'last_5_avg'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'next_to_faster',
#    'pir3'],
#   '590': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'pir3'],
#   '340': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_in_race_pos',
#    'pir3']},
#  'capalaba': {'366': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form2',
#    'mean_place',
#    'at_cas_perc',
#    'last_5_avg']},
#  'wagga': {'525': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'last_5_avg',
#    'pred_split2',
#    'csplit_z_avg'],
#   '400': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'last_5_avg',
#    'time_z_avg',
#    'ctime_z_avg',
#    'in_form2',
#    'i1'],
#   '320': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'last_5_avg',
#    'in_form',
#    'in_form2',
#    'ctime_z_avg',
#    'mean_in_race_pos']},
#  'nowra': {'365': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form',
#    'collision',
#    'csplit_z_avg',
#    'mean_in_race_pos',
#    'pred_split2'],
#   '520': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir2',
#    'at_cas_perc'],
#   '630': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_in_race_pos']},
#  'bundaberg': {'460': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'ctime_z_avg',
#    'first_out',
#    'pred_split2',
#    'next_to_faster'],
#   '550': ['faster_inside', 'at_cas_dist_time_avg', 'mean_place', 't3'],
#   '531': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'i1',
#    'next_to_faster',
#    'at_cas_dist_time'],
#   '315': ['faster_inside',
#    'at_cas_dist_time_avg',
#    'at_cas_perc',
#    'in_form',
#    'i2']},
#  'goulburn': {'350': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'pir3',
#    'last_5_avg'],
#   '440': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'in_form2',
#    'ctime_z_avg',
#    'csplit_z_avg',
#    'pred_split1']},
#  'the meadows': {'525': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'time_z_avg',
#    'mean_in_race_pos',
#    'pred_split1'],
#   '600': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'ctime_z_avg',
#    'csplit_z_avg',
#    'collision',
#    'pred_split1',
#    'at_cas_dist_time'],
#   '725': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'pred_split1',
#    'next_to_faster'],
#   '730': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'ctime_z_avg',
#    'collision']},
#  'sandown park': {'515': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'at_cas_perc',
#    'time_z_avg',
#    'in_form2',
#    'ctime_z_avg'],
#   '595': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'at_cas_perc',
#    'pir1',
#    'last_5_avg'],
#   '715': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'time_z_avg',
#    'csplit_z_avg',
#    'ctime_z_avg',
#    'first_out']},
#  'richmond (ris)': {'324': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'last_5_avg',
#    'mean_place',
#    'pir3',
#    'at_cas_dist_time',
#    'pir1',
#    'i1',
#    't2']},
#  'richmond straight': {'324': ['split_z_avg',
#    'last_5_avg',
#    'at_cas_dist_time',
#    'mean_place',
#    'pir3',
#    'at_cas_perc',
#    'collision',
#    'i1',
#    'mean_in_race_pos']},
#  'murray bridge': {'395': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'at_cas_dist_time',
#    'last_5_avg',
#    'time_z_avg'],
#   '455': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'last_5_avg'],
#   '530': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir2',
#    'in_form'],
#   '300': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'ctime_z_avg',
#    'mean_place',
#    'at_cas_perc',
#    'pir3'],
#   '350': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'mean_place',
#    'pred_split1',
#    'last_5_avg',
#    'next_to_faster'],
#   '680': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form',
#    'mean_in_race_pos',
#    'in_form2',
#    'ctime_z_avg',
#    'first_out']},
#  'muswellbrook': {'429': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'in_form',
#    'mean_in_race_pos'],
#   '560': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '328': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg',
#    'pir2',
#    'at_cas_dist_time'],
#   '336': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg'],
#   '431': ['at_cas_dist_time_avg',
#    'faster_inside',
#    'i2',
#    'i1',
#    'split_z_avg',
#    'last_5_avg']}}

# %%
plt.scatter(data2['at_cas_dist_time_avg'],data2['RunTime'])
