# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
files = os.listdir('bsp')
files = [x for x in files if '.D' not in x]
# files=files[-1:]
files.sort()
print(files)
for file in files:
    if(file==files[0]):
        print(True)
        df = pd.read_csv('bsp/'+file)
        df['date']=pd.to_datetime(df['date']).astype(str)
        
    else:
        df_temp = pd.read_csv('bsp/'+file)
        df_temp['date']=pd.to_datetime(df_temp['date']).astype(str)
        df = pd.concat([df,df_temp])


df = df.rename(columns={'track':'Track','name':'DogName'})

df['Track']=df['Track'].str.strip()
df['DogName']=df['DogName'].str.strip()
df['date']=df['date'].str.strip()


df['menu_day'] = df['MENU_HINT'].str.extract(r'(\d{1,2})\D+(\w+)')[0].astype(str)
df['menu_month']=df['MENU_HINT'].str.split(' ').str[-1].str[:3]
df['menu_yr']=df['date'].str[:4]

df['date']=df['menu_day']+'-'+df['menu_month']+'-'+df['menu_yr'].astype(str)
df['date']=pd.to_datetime(df['date'],format="%d-%b-%Y", errors='coerce').astype(str)
df = df.dropna(subset=['date'])
df = df.drop(['menu_day', 'menu_month', 'menu_yr'], axis=1)
df
# Out:
# ['bsp2018.csv', 'bsp2019.csv', 'bsp2020.csv', 'bsp2021.csv', 'bsp2022.csv', 'bsp2023.csv', 'bsp2024.csv', 'bsp2025_0.csv', 'bsp2025_1.csv']
# True
#        Unnamed: 0         Track                   MENU_HINT        date  \
# 0               1    shepparton   AUS / Shep (AUS) 31st May  2018-05-31
# 1               2    shepparton   AUS / Shep (AUS) 31st May  2018-05-31
# 2               3      maitland   AUS / Mait (AUS) 31st May  2018-05-31
# 3               4      ballarat   AUS / Ball (AUS) 31st May  2018-05-31
# 4               5  sandown park   AUS / SPrk (AUS) 31st May  2018-05-31
# ...           ...           ...                         ...         ...
# 11765        1567         dubbo        Dubbo (AUS) 17th Feb  2024-02-17
# 11766        1572   the gardens  The Gardens (AUS) 17th Feb  2024-02-17
# 11767        1573       ipswich      Ipswich (AUS) 17th Feb  2024-02-17
# 11768        1576         dubbo        Dubbo (AUS) 17th Feb  2024-02-17
# 11769        1577    shepparton   Shepparton (AUS) 17th Feb  2024-02-17
#
#                DogName         BSP  MORNINGWAP  PPTRADEDVOL
# 0          stella view   23.645034   20.737885         0.00
# 1          bear cabang  133.614102   46.303718         0.00
# 2        potters flash   52.393295   23.380410         0.00
# 3          cosmic spur    6.400000    1.000000         0.00
# 4      shaes intention   12.549408    8.239423         0.00
# ...                ...         ...         ...          ...
# 11765   who knows nash   23.000000   11.051400       420.69
# 11766     bunt and run   17.586628    1.000000       889.42
# 11767     maywyns luck   27.886338    1.000000       165.15
# 11768     enough power    4.227212    3.279300      2071.06
# 11769     aston cornes    6.200000    5.073700      1863.85
#
# [1786886 rows x 8 columns]

# %%
trks = ['shepparton', 'maitland', 'ballarat', 'sandown park', 'goulburn', 'hobart', 'dapto', 'angle park', 'warrnambool', 'warragul', 'albion park', 'northam', 'traralgon', 'healesville', 'richmond', 'ipswich', 'geelong', 'casino', 'the gardens', 'cannington', 'mount gambier', 'dubbo', 'bendigo', 'bulli', 'horsham', 'wentworth park', 'the meadows', 'sale', 'darwin', 'gawler', 'grafton', 'nowra', 'bathurst', 'launceston', 'townsville', 'devonport', 'lismore', 'rockhampton', 'cranbourne', 'strathalbyn', 'wagga', 'cairns', 'mandurah', 'temora', 'gosford', 'capalaba', 'murray bridge', 'angle park', 'ipswich', 'bundaberg', 'gunnedah', 'taree']
races = pd.read_csv('allRaces1.csv')
races = races[races['Track'].isin(trks)]

char = "'"
races['DogName']=races['DogName'].str.replace(char,'').str.replace('.','')

races['Track']=races['Track'].str.strip()
races['DogName']=races['DogName'].astype(str).str.strip()
races['date']=races['date'].astype(str).str.strip()



races2 = pd.merge(races,df,on=['DogName','date','Track'],how='left')
races2 = races2.dropna(subset=['Place'])
races2
# Out:
# /var/folders/_5/kty37fps3g723664y0dwx0_80000gn/T/ipykernel_23377/1012838655.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   races['DogName']=races['DogName'].str.replace(char,'').str.replace('.','')
#          Place          DogName  Box  Weight  StartPrice   PIR  Split  \
# 0          1.0      raine allen  1.0    27.4         2.4   111   6.68
# 1          2.0       surf a lot  2.0    32.8         6.3   332   7.01
# 2          3.0       pingin bee  6.0    25.5         9.3   443   7.24
# 3          4.0  lucas the great  7.0    32.2         9.1   655   7.31
# 4          5.0            quavo  4.0    28.9         3.4   766   7.38
# ...        ...              ...  ...     ...         ...   ...    ...
# 1765644    1.0     rockstar sue  3.0    27.9         3.2  31.0   8.72
# 1765645    2.0  angry firestorm  2.0    31.4         3.8  22.0   8.69
# 1765647    8.0      boy serious  8.0    31.6        51.0  88.0   9.30
# 1765648    1.0       ocean king  7.0    28.1        31.0  11.0   8.55
# 1765649    7.0       miss narla  4.0    23.7        21.0  77.0   9.08
#
#          RunTime     RaceId  Distance       RaceGrade    Track        date  \
# 0          28.66  335811282       500  Restricted Win  bendigo  2018-07-01
# 1          28.82  335811282       500  Restricted Win  bendigo  2018-07-01
# 2          28.93  335811282       500  Restricted Win  bendigo  2018-07-01
# 3          29.03  335811282       500  Restricted Win  bendigo  2018-07-01
# 4          29.05  335811282       500  Restricted Win  bendigo  2018-07-01
# ...          ...        ...       ...             ...      ...         ...
# 1765644    21.05  996299913       365               5    nowra  2024-02-19
# 1765645    21.10  996299913       365               5    nowra  2024-02-19
# 1765647    21.81  996299912       365          Maiden    nowra  2024-02-19
# 1765648    21.02  996299912       365          Maiden    nowra  2024-02-19
# 1765649    21.53  996299914       365               7    nowra  2024-02-19
#
#         TrainerLName TrainerFName  Unnamed: 0                 MENU_HINT  \
# 0           Grenfell            C       457.0  AUS / Bend (AUS) 1st Jul
# 1              Tyley            C       119.0  AUS / Bend (AUS) 1st Jul
# 2            Dapiran            P       746.0  AUS / Bend (AUS) 1st Jul
# 3           Hamilton            E       520.0  AUS / Bend (AUS) 1st Jul
# 4            Dapiran            P       392.0  AUS / Bend (AUS) 1st Jul
# ...              ...          ...         ...                       ...
# 1765644          poo          poo         NaN                       NaN
# 1765645          poo          poo         NaN                       NaN
# 1765647          poo          poo         NaN                       NaN
# 1765648          poo          poo         NaN                       NaN
# 1765649          poo          poo         NaN                       NaN
#
#                BSP  MORNINGWAP  PPTRADEDVOL
# 0         2.485728    2.402235          0.0
# 1        10.000000    8.224462          0.0
# 2        12.362569    8.322981          0.0
# 3         8.013214    5.076427          0.0
# 4         3.820639    2.578982          0.0
# ...            ...         ...          ...
# 1765644        NaN         NaN          NaN
# 1765645        NaN         NaN          NaN
# 1765647        NaN         NaN          NaN
# 1765648        NaN         NaN          NaN
# 1765649        NaN         NaN          NaN
#
# [1753587 rows x 20 columns]

# %%
nonjoin = races2[races2['BSP'].isna()]
nonjoin
# Out:
#          Place          DogName  Box  Weight  StartPrice   PIR  Split  \
# 342        1.0       mount duke  6.0    33.2        15.0   NaN    NaN
# 343        2.0      teacup toni  5.0    28.2         3.5   NaN    NaN
# 344        3.0      bourne bill  2.0    30.5         4.6   NaN    NaN
# 345        4.0        go saints  8.0    27.3        10.0   NaN    NaN
# 346        5.0      little lina  1.0    27.4        12.0   NaN    NaN
# ...        ...              ...  ...     ...         ...   ...    ...
# 1765644    1.0     rockstar sue  3.0    27.9         3.2  31.0   8.72
# 1765645    2.0  angry firestorm  2.0    31.4         3.8  22.0   8.69
# 1765647    8.0      boy serious  8.0    31.6        51.0  88.0   9.30
# 1765648    1.0       ocean king  7.0    28.1        31.0  11.0   8.55
# 1765649    7.0       miss narla  4.0    23.7        21.0  77.0   9.08
#
#          RunTime     RaceId  Distance RaceGrade          Track        date  \
# 342        30.51  334311904       512    Maiden  mount gambier  2018-07-01
# 343        30.64  334311904       512    Maiden  mount gambier  2018-07-01
# 344        30.66  334311904       512    Maiden  mount gambier  2018-07-01
# 345        30.76  334311904       512    Maiden  mount gambier  2018-07-01
# 346        30.92  334311904       512    Maiden  mount gambier  2018-07-01
# ...          ...        ...       ...       ...            ...         ...
# 1765644    21.05  996299913       365         5          nowra  2024-02-19
# 1765645    21.10  996299913       365         5          nowra  2024-02-19
# 1765647    21.81  996299912       365    Maiden          nowra  2024-02-19
# 1765648    21.02  996299912       365    Maiden          nowra  2024-02-19
# 1765649    21.53  996299914       365         7          nowra  2024-02-19
#
#         TrainerLName TrainerFName  Unnamed: 0 MENU_HINT  BSP  MORNINGWAP  \
# 342            Perry            N         NaN       NaN  NaN         NaN
# 343             Weis            B         NaN       NaN  NaN         NaN
# 344          Peckham            D         NaN       NaN  NaN         NaN
# 345           Wilson            W         NaN       NaN  NaN         NaN
# 346          Fennell            D         NaN       NaN  NaN         NaN
# ...              ...          ...         ...       ...  ...         ...
# 1765644          poo          poo         NaN       NaN  NaN         NaN
# 1765645          poo          poo         NaN       NaN  NaN         NaN
# 1765647          poo          poo         NaN       NaN  NaN         NaN
# 1765648          poo          poo         NaN       NaN  NaN         NaN
# 1765649          poo          poo         NaN       NaN  NaN         NaN
#
#          PPTRADEDVOL
# 342              NaN
# 343              NaN
# 344              NaN
# 345              NaN
# 346              NaN
# ...              ...
# 1765644          NaN
# 1765645          NaN
# 1765647          NaN
# 1765648          NaN
# 1765649          NaN
#
# [45420 rows x 20 columns]

# %%
races2 = races2.drop_duplicates(keep='first')
races2.to_csv('bsp_allRaces.csv')
races2
